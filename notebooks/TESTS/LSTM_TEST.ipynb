# %%
import tensorflow as tf
import numpy as np

from src.common.analysis_and_plots import Visualize as V
from src.features.build_features import FeatureEngineering as FE
from src.common.globals import G
from src.common.globals import split_train_valid_test, get_naive_forecast, calc_errors, save_errors_to_table
from src.data.get_data import CSVsLoader
from src.common.logs import setup_logging, log_model_info

import logging
import os
from datetime import datetime

logger = setup_logging(logger_name=__name__,
                        console_level=logging.INFO, 
                        log_file_level=logging.INFO)

PROJECT_PATH = G.get_project_root()
DATA_DIR_PROCESSED = os.path.join(PROJECT_PATH, r'data\03_processed\daily_full')

config = {
    'AV': {
        'key': '',
        'ticker': 'MSFT',
        'outputsize': 'full',
        'key_adjusted_close': 'Adj Close',
        'key_volume': 'Volume',
    },
    'data': {
        'test_size': 0.05,
    }, 
    'model': {
        'name': 'LSTM', 
        'window': 20,
        'batch_size' : 32,
        'shuffle_buffer_size' : 1000, # https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
        'epochs' : 30,
        'optimizer': tf.keras.optimizers.Adam(),
        'loss': tf.keras.losses.Huber(),
    },
}

# %%
def label_column_to_end(df, last_column):
    ''' 
    Changes positions of columns in df to put the target column at the end

    Args:
        df (pandas dataframe) - dataframe to change
        last_column (string) - name of the column to put at the end
        
    Returns:
        df (pandas dataframe) - dataframe with the target column at the end
    '''
    cols = df.columns.tolist()
    cols.remove(last_column)
    cols.append(last_column)
    return df[cols]

# %%
def windowed_dataset(df, window_size, batch_size, shuffle_buffer, verbose=True):
    """Generates dataset windows

    Args:
    series (array of float) - contains the values of the time series
    window_size (int) - the number of time steps to include in the feature
    batch_size (int) - the batch size
    shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
    dataset (TF Dataset) - TF Dataset containing time windows
    """
    # change the position of the target column to the end
    df = label_column_to_end(df, 'Adj Close')
    
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(df)
    if verbose:
        print('--------------------------from_tensor_slices--------------------------')
        for element in dataset:
            print(element)
            break
        print('-'*100)

    # Window the data but only take those with the specified size
    # And add + 1 to the window size to account for the label, which we will separate later
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    if verbose:
        print('-------------------------------window-----------------------------------')
        for window in dataset:
            for element in window:
                print(element)
            break
        print('-'*100)
    
    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
    if verbose:
        print('--------------------------------flat_map--------------------------------')
        for window in dataset:
            print(window)
            break
        print('-'*100)

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1][-1]))
    if verbose:
        print('------------.map(lambda window: (window[:-1], window[-1][-1]))--------------')
        for x,y in dataset:
            print(x, y)
            break
        print('-'*100)

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    if verbose:
        print('--------------------------------batch-----------------------------------')
        for x,y in dataset:
            print(x.numpy(), y.numpy())
            break
        print('-'*100)

    return dataset

# %%
# -----------------------------Data----------------------------------------
df = CSVsLoader(ticker=config['AV']['ticker'], directory=DATA_DIR_PROCESSED)

test_size_int = int(len(df) * config['data']['test_size'])
df_train = df.iloc[:-test_size_int].copy(deep=True)
df_test = df.iloc[-test_size_int:].copy(deep=True)

# Normalize data with MinMaxScaler()
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
for col in df_train.columns:
    df_train[col] = scaler.fit_transform(df_train[col].values.reshape(-1,1))

train_dataset = windowed_dataset(df_train, 
                                window_size=config['model']['window'], 
                                batch_size=config['model']['batch_size'], 
                                shuffle_buffer=config['model']['shuffle_buffer_size'])
# Out:
# 2023-09-19 23:32:01 - src.data.get_data - INFO - Loaded "..\P7-Trading-Bot\data\03_processed\daily_full\MSFT-daily-full.csv". Number data points 5995. From "1999-11-01 00:00:00" to "2023-08-29 00:00:00"
# --------------------------from_tensor_slices--------------------------
# tf.Tensor([0.0355088  0.05339881], shape=(2,), dtype=float64)
# ----------------------------------------------------------------------------------------------------
# -------------------------------window-----------------------------------
# tf.Tensor([0.0355088  0.05339881], shape=(2,), dtype=float64)
# tf.Tensor([0.02960297 0.05358007], shape=(2,), dtype=float64)
# tf.Tensor([0.0280377  0.05304583], shape=(2,), dtype=float64)
# tf.Tensor([0.03634458 0.05280732], shape=(2,), dtype=float64)
# tf.Tensor([0.04995357 0.05262606], shape=(2,), dtype=float64)
# tf.Tensor([0.19832283 0.05108055], shape=(2,), dtype=float64)
# tf.Tensor([0.08379013 0.05005975], shape=(2,), dtype=float64)
# tf.Tensor([0.04928543 0.04839022], shape=(2,), dtype=float64)
# tf.Tensor([0.04919076 0.05077526], shape=(2,), dtype=float64)
# tf.Tensor([0.0322219  0.05036504], shape=(2,), dtype=float64)
# tf.Tensor([0.03022788 0.04827574], shape=(2,), dtype=float64)
# tf.Tensor([0.04055322 0.04857148], shape=(2,), dtype=float64)
# tf.Tensor([0.04709268 0.04636771], shape=(2,), dtype=float64)
# tf.Tensor([0.0451055  0.04631046], shape=(2,), dtype=float64)
# tf.Tensor([0.03975076 0.04732172], shape=(2,), dtype=float64)
# tf.Tensor([0.06740842 0.05095653], shape=(2,), dtype=float64)
# tf.Tensor([0.0504833  0.05077526], shape=(2,), dtype=float64)
# tf.Tensor([0.03594438 0.05275008], shape=(2,), dtype=float64)
# tf.Tensor([0.0143648  0.05220629], shape=(2,), dtype=float64)
# tf.Tensor([0.03397001 0.05131905], shape=(2,), dtype=float64)
# tf.Tensor([0.04480851 0.05213951], shape=(2,), dtype=float64)
# ----------------------------------------------------------------------------------------------------
# --------------------------------flat_map--------------------------------
# tf.Tensor(
# [[0.0355088  0.05339881]
#  [0.02960297 0.05358007]
#  [0.0280377  0.05304583]
#  [0.03634458 0.05280732]
#  [0.04995357 0.05262606]
#  [0.19832283 0.05108055]
#  [0.08379013 0.05005975]
#  [0.04928543 0.04839022]
#  [0.04919076 0.05077526]
#  [0.0322219  0.05036504]
#  [0.03022788 0.04827574]
#  [0.04055322 0.04857148]
#  [0.04709268 0.04636771]
#  [0.0451055  0.04631046]
#  [0.03975076 0.04732172]
#  [0.06740842 0.05095653]
#  [0.0504833  0.05077526]
#  [0.03594438 0.05275008]
#  [0.0143648  0.05220629]
#  [0.03397001 0.05131905]
#  [0.04480851 0.05213951]], shape=(21, 2), dtype=float64)
# ----------------------------------------------------------------------------------------------------
# ------------.map(lambda window: (window[:-1], window[-1][-1]))--------------
# tf.Tensor(
# [[0.0355088  0.05339881]
#  [0.02960297 0.05358007]
#  [0.0280377  0.05304583]
#  [0.03634458 0.05280732]
#  [0.04995357 0.05262606]
#  [0.19832283 0.05108055]
#  [0.08379013 0.05005975]
#  [0.04928543 0.04839022]
#  [0.04919076 0.05077526]
#  [0.0322219  0.05036504]
#  [0.03022788 0.04827574]
#  [0.04055322 0.04857148]
#  [0.04709268 0.04636771]
#  [0.0451055  0.04631046]
#  [0.03975076 0.04732172]
#  [0.06740842 0.05095653]
#  [0.0504833  0.05077526]
#  [0.03594438 0.05275008]
#  [0.0143648  0.05220629]
#  [0.03397001 0.05131905]], shape=(20, 2), dtype=float64) tf.Tensor(0.05213950894862625, shape=(), dtype=float64)
# ----------------------------------------------------------------------------------------------------
# --------------------------------batch-----------------------------------
# [[[0.03984919 0.01665961]
#   [0.05954958 0.01727972]
#   [0.08173989 0.01809064]
#   ...
#   [0.04847408 0.01807156]
#   [0.05123757 0.01819558]
#   [0.04456688 0.01634478]]
#
#  [[0.05426149 0.02061742]
#   [0.05719313 0.02036856]
#   [0.04955644 0.02017714]
#   ...
#   [0.133587   0.0154556 ]
#   [0.09511871 0.01551334]
#   [0.10652572 0.01576357]]
#
#  [[0.25798315 0.02883287]
#   [0.12629481 0.03145642]
#   [0.08150151 0.03014941]
#   ...
#   [0.0354924  0.02985367]
#   [0.03583279 0.02842264]
#   [0.04688676 0.0273446 ]]
#
#  ...
#
#  [[0.11734097 0.00486796]
#   [0.12941818 0.00671875]
#   [0.08360387 0.0095808 ]
#   ...
#   [0.05224065 0.01578191]
#   [0.08380636 0.0182242 ]
#   [0.16887109 0.02347129]]
#
#  [[0.03729759 0.0325917 ]
#   [0.02701258 0.03247722]
#   [0.02110436 0.03312595]
#   ...
#   [0.03769677 0.02389106]
#   [0.04856003 0.02574185]
#   [0.03696727 0.02495956]]
#
#  [[0.05714563 0.02896643]
#   [0.06203505 0.02971057]
#   [0.         0.02945298]
#   ...
#   [0.04293718 0.03002539]
#   [0.05746432 0.03192389]
#   [0.08154355 0.02833678]]] [0.01680271 0.01551334 0.02651461 0.01786089 0.02305153 0.0185581
#  0.01900649 0.02991091 0.03453789 0.03235319 0.02431083 0.01493284
#  0.0095808  0.02923356 0.0329256  0.03014941 0.02097177 0.00671875
#  0.01377848 0.01750869 0.01709846 0.05864591 0.02048342 0.01229975
#  0.0140898  0.01135241 0.03611202 0.03407996 0.01702214 0.0226413
#  0.02686759 0.02677219]
# ----------------------------------------------------------------------------------------------------

# %%
# -----------------------------Model Architecture--------------------------
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(128, activation="relu", input_shape=[config['model']['window'], 2]),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dense(32, activation="relu"),
        tf.keras.layers.Dense(1),
        ],
    name=config['model']['name'])

model._name = f"{model._name}_{str(model.count_params())}_{datetime.now().strftime('%Y-%m-%d--%H-%M')}"
log_model_info(config, model, logger)
# Out:
# 2023-09-19 23:32:02 - __main__ - INFO - ==============================================================================================
# 2023-09-19 23:32:02 - __main__ - INFO - =================================== MODEL CONFIG AND SETUP ===================================
# 2023-09-19 23:32:02 - __main__ - INFO - ==============================================================================================
# 2023-09-19 23:32:02 - __main__ - INFO - AV_key: , AV_ticker: MSFT, AV_outputsize: full, AV_key_adjusted_close: Adj Close, AV_key_volume: Volume,
# 2023-09-19 23:32:02 - __main__ - INFO - data_test_size: 0.05,
# 2023-09-19 23:32:02 - __main__ - INFO - ----------------------------------------------------------------------
# 2023-09-19 23:32:02 - __main__ - INFO - model_name: LSTM
# 2023-09-19 23:32:02 - __main__ - INFO - model_window: 20
# 2023-09-19 23:32:02 - __main__ - INFO - model_batch_size: 32
# 2023-09-19 23:32:02 - __main__ - INFO - model_shuffle_buffer_size: 1000
# 2023-09-19 23:32:02 - __main__ - INFO - model_epochs: 30
# 2023-09-19 23:32:02 - __main__ - INFO - model_optimizer: <keras.src.optimizers.adam.Adam object at 0x00000271AF835BD0>
# 2023-09-19 23:32:02 - __main__ - INFO - model_loss: <keras.src.losses.Huber object at 0x00000271AFE28910>
# 2023-09-19 23:32:02 - __main__ - INFO - Model: "LSTM_10753_2023-09-19--23-32"
# 2023-09-19 23:32:02 - __main__ - INFO - _________________________________________________________________
# 2023-09-19 23:32:02 - __main__ - INFO -  Layer (type)                Output Shape              Param #
# 2023-09-19 23:32:02 - __main__ - INFO - =================================================================
# 2023-09-19 23:32:02 - __main__ - INFO -  dense (Dense)               (None, 20, 128)           384
# 2023-09-19 23:32:02 - __main__ - INFO -
# 2023-09-19 23:32:02 - __main__ - INFO -  dense_1 (Dense)             (None, 20, 64)            8256
# 2023-09-19 23:32:02 - __main__ - INFO -
# 2023-09-19 23:32:02 - __main__ - INFO -  dense_2 (Dense)             (None, 20, 32)            2080
# 2023-09-19 23:32:02 - __main__ - INFO -
# 2023-09-19 23:32:02 - __main__ - INFO -  dense_3 (Dense)             (None, 20, 1)             33
# 2023-09-19 23:32:02 - __main__ - INFO -
# 2023-09-19 23:32:02 - __main__ - INFO - =================================================================
# 2023-09-19 23:32:02 - __main__ - INFO - Total params: 10753 (42.00 KB)
# 2023-09-19 23:32:02 - __main__ - INFO - Trainable params: 10753 (42.00 KB)
# 2023-09-19 23:32:02 - __main__ - INFO - Non-trainable params: 0 (0.00 Byte)
# 2023-09-19 23:32:02 - __main__ - INFO - _________________________________________________________________

# %%
# Set the training parameters and train the model
model.compile(loss=config['model']['loss'], 
            optimizer=config['model']['optimizer'], 
            metrics=["mae"],
            )    

# Train the model
history = model.fit(train_dataset, epochs=config['model']['epochs'])

# Plot MAE and Loss
mae=history.history['mae']
loss=history.history['loss']
zoom = int(len(mae) * 1)
V.plot_series(x=range(config['model']['epochs'])[-zoom:],
                y=(mae[-zoom:],loss[-zoom:]),
                model_name=config['model']['name'],
                title='MAE_and_Loss',
                xlabel='MAE',
                ylabel='Loss',
                legend=['MAE', 'Loss']
            )

# Save the model
FE.model_save(model, logger)
# Out:
# Epoch 1/30
# 178/178 [==============================] - 2s 8ms/step - loss: 0.0117 - mae: 0.0836
# Epoch 2/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0133 - mae: 0.0983
# Epoch 3/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0133 - mae: 0.0987
# Epoch 4/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0136 - mae: 0.0999
# Epoch 5/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0139 - mae: 0.1026
# Epoch 6/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0145 - mae: 0.1063
# Epoch 7/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0151 - mae: 0.1081
# Epoch 8/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0174 - mae: 0.1171
# Epoch 9/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0168 - mae: 0.1138
# Epoch 10/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0150 - mae: 0.1062
# Epoch 11/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0187 - mae: 0.1224
# Epoch 12/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0187 - mae: 0.1250
# Epoch 13/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0156 - mae: 0.1179
# Epoch 14/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0162 - mae: 0.1154
# Epoch 15/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0177 - mae: 0.1189
# Epoch 16/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0175 - mae: 0.1185
# Epoch 17/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0152 - mae: 0.1116
# Epoch 18/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0175 - mae: 0.1178
# Epoch 19/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0177 - mae: 0.1201
# Epoch 20/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0177 - mae: 0.1198
# Epoch 21/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0180 - mae: 0.1222
# Epoch 22/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0181 - mae: 0.1237
# Epoch 23/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0179 - mae: 0.1229
# Epoch 24/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0175 - mae: 0.1206
# Epoch 25/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0174 - mae: 0.1205
# Epoch 26/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0173 - mae: 0.1198
# Epoch 27/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0165 - mae: 0.1141
# Epoch 28/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0175 - mae: 0.1205
# Epoch 29/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0175 - mae: 0.1218
# Epoch 30/30
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0174 - mae: 0.1199
# 2023-09-19 23:32:21 - src.common.analysis_and_plots - INFO - Plot "LSTM-MAE_and_Loss-2023-09-19_23-32-21-5.png" saved to "D:\Study 2018 and later\Mignimind Bootcamp\Code\P7-Trading-Bot\figures\LSTM-MAE_and_Loss-2023-09-19_23-32-21-5.png"
# 2023-09-19 23:32:21 - __main__ - INFO - Model saved as LSTM_10753_2023-09-19--23-32.h5

# %%
def model_forecast(model, series, window_size, batch_size):
    # calculate actual prediction size 
    prediction_size = len(series) - window_size
    print('prediction_size', prediction_size)

    # calculate number of points we need to add to make series evenly divisible by window_size
    remainder = prediction_size % window_size
    remainder = window_size - remainder if remainder > 0 else 0
    print('remainder', remainder)

    # get last prediction_size + remainder points from series
    series = series[-(prediction_size + remainder):]
    print('Paddded series to predict on', series)

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)
    print('--------------------------from_tensor_slices--------------------------')
    for i,element in enumerate(dataset):
        print(element)
        print(i)
    print('-'*100)

    # Batch the data to window size
    dataset = dataset.batch(window_size)
    print('--------------------------------Batch to window size--------------------------------')
    for i,x in enumerate(dataset):
        print(i,x)
    print('-'*100)


    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    print('--------------------------------Batch to Batch size-----------------------------------')
    for x in dataset:
        print(x)
        break
    print('-'*100)
  
    # Get predictions on the entire dataset
    forecast = model.predict(dataset)
    print('--------------------------------forecast-----------------------------------')
    for i,x in enumerate(forecast):
        if i > 1:
            break
        print(i,x)
    print('-'*100)

    forecast = forecast.squeeze()

    # flatten the forecast array
    forecast = forecast.flatten()
    # get the last prediction_size points
    forecast = forecast[-prediction_size:]

    return forecast

# %%
# -----------------------------Predictions---------------------------------
forecast_series = df.iloc[-test_size_int - config['model']['window']:]

results = model_forecast(model=model, 
                            series=forecast_series, 
                            window_size=config['model']['window'], 
                            batch_size=config['model']['batch_size'])
print(results.shape)
# unnormalize the data
# results = scaler.inverse_transform(results.reshape(-1,1))

V.plot_series(  x=df_test.index, 
                y=(df_test['Adj Close'], results),
                model_name=config['model']['name'])
# Out:
# prediction_size 299
# remainder 1
# Paddded series to predict on              Adj Close    Volume
# Date
# 2022-06-21  250.778474  29928297
# 2022-06-22  250.175593  25961215
# 2022-06-23  255.838716  25861449
# 2022-06-24  264.575540  33923231
# 2022-06-27  261.798337  24615114
# ...                ...       ...
# 2023-08-23  327.000000  21166382
# 2023-08-24  319.970000  23281434
# 2023-08-25  322.980000  21684104
# 2023-08-28  323.700000  14808482
# 2023-08-29  328.410000  19284590
#
# [300 rows x 2 columns]
# --------------------------from_tensor_slices--------------------------
# tf.Tensor([2.50778474e+02 2.99282970e+07], shape=(2,), dtype=float64)
# 0
# tf.Tensor([2.50175593e+02 2.59612150e+07], shape=(2,), dtype=float64)
# 1
# tf.Tensor([2.55838716e+02 2.58614490e+07], shape=(2,), dtype=float64)
# 2
# tf.Tensor([2.6457554e+02 3.3923231e+07], shape=(2,), dtype=float64)
# 3
# tf.Tensor([2.61798337e+02 2.46151140e+07], shape=(2,), dtype=float64)
# 4
# tf.Tensor([2.53486494e+02 2.73802470e+07], shape=(2,), dtype=float64)
# 5
# tf.Tensor([2.57222376e+02 2.00698390e+07], shape=(2,), dtype=float64)
# 6
# tf.Tensor([2.53832409e+02 3.17308680e+07], shape=(2,), dtype=float64)
# 7
# tf.Tensor([2.56550312e+02 2.28376920e+07], shape=(2,), dtype=float64)
# 8
# tf.Tensor([2.59782146e+02 2.29716340e+07], shape=(2,), dtype=float64)
# 9
# tf.Tensor([2.6310293e+02 2.3824419e+07], shape=(2,), dtype=float64)
# 10
# tf.Tensor([2.6526737e+02 2.0859874e+07], shape=(2,), dtype=float64)
# 11
# tf.Tensor([2.64536006e+02 1.96587510e+07], shape=(2,), dtype=float64)
# 12
# tf.Tensor([2.61422772e+02 1.95191080e+07], shape=(2,), dtype=float64)
# 13
# tf.Tensor([2.50709291e+02 3.58684500e+07], shape=(2,), dtype=float64)
# 14
# tf.Tensor([2.49770379e+02 2.94974230e+07], shape=(2,), dtype=float64)
# 15
# tf.Tensor([2.51114505e+02 2.51028230e+07], shape=(2,), dtype=float64)
# 16
# tf.Tensor([2.53723693e+02 2.97740500e+07], shape=(2,), dtype=float64)
# 17
# tf.Tensor([2.51282521e+02 2.09750340e+07], shape=(2,), dtype=float64)
# 18
# tf.Tensor([2.56500896e+02 2.50125620e+07], shape=(2,), dtype=float64)
# 19
# tf.Tensor([2.59208916e+02 2.27882820e+07], shape=(2,), dtype=float64)
# 20
# tf.Tensor([2.6174892e+02 2.2404675e+07], shape=(2,), dtype=float64)
# 21
# tf.Tensor([2.57321208e+02 2.18812900e+07], shape=(2,), dtype=float64)
# 22
# tf.Tensor([2.55809066e+02 2.10559980e+07], shape=(2,), dtype=float64)
# 23
# tf.Tensor([2.48959949e+02 3.93479570e+07], shape=(2,), dtype=float64)
# 24
# tf.Tensor([2.65603401e+02 4.59940490e+07], shape=(2,), dtype=float64)
# 25
# tf.Tensor([2.73183881e+02 3.34593270e+07], shape=(2,), dtype=float64)
# 26
# tf.Tensor([2.77463343e+02 3.21527520e+07], shape=(2,), dtype=float64)
# 27
# tf.Tensor([2.74765206e+02 2.15395800e+07], shape=(2,), dtype=float64)
# 28
# tf.Tensor([2.71612439e+02 2.27541840e+07], shape=(2,), dtype=float64)
# 29
# tf.Tensor([2.79173152e+02 2.35188740e+07], shape=(2,), dtype=float64)
# 30
# tf.Tensor([2.80339379e+02 1.80986680e+07], shape=(2,), dtype=float64)
# 31
# tf.Tensor([2.79608016e+02 1.67746060e+07], shape=(2,), dtype=float64)
# 32
# tf.Tensor([2.77048245e+02 1.87578180e+07], shape=(2,), dtype=float64)
# 33
# tf.Tensor([2.79005136e+02 2.34052380e+07], shape=(2,), dtype=float64)
# 34
# tf.Tensor([2.85785069e+02 2.46878450e+07], shape=(2,), dtype=float64)
# 35
# tf.Tensor([2.83670046e+02 2.00659380e+07], shape=(2,), dtype=float64)
# 36
# tf.Tensor([2.88502973e+02 2.26196750e+07], shape=(2,), dtype=float64)
# 37
# tf.Tensor([2.90044765e+02 1.80856540e+07], shape=(2,), dtype=float64)
# 38
# tf.Tensor([2.89293635e+02 1.81028820e+07], shape=(2,), dtype=float64)
# 39
# tf.Tensor([2.88532622e+02 1.82533580e+07], shape=(2,), dtype=float64)
# 40
# tf.Tensor([2.87393626e+02 1.71861920e+07], shape=(2,), dtype=float64)
# 41
# tf.Tensor([2.8341209e+02 2.0570033e+07], shape=(2,), dtype=float64)
# 42
# tf.Tensor([2.75092462e+02 2.50610700e+07], shape=(2,), dtype=float64)
# 43
# tf.Tensor([2.73794996e+02 1.75274090e+07], shape=(2,), dtype=float64)
# 44
# tf.Tensor([2.73151215e+02 1.81370190e+07], shape=(2,), dtype=float64)
# 45
# tf.Tensor([2.76181937e+02 1.65834070e+07], shape=(2,), dtype=float64)
# 46
# tf.Tensor([2.65524889e+02 2.75493070e+07], shape=(2,), dtype=float64)
# 47
# tf.Tensor([2.62692254e+02 2.01213710e+07], shape=(2,), dtype=float64)
# 48
# tf.Tensor([2.60453878e+02 2.27670710e+07], shape=(2,), dtype=float64)
# 49
# tf.Tensor([2.5896823e+02 2.4791834e+07], shape=(2,), dtype=float64)
# 50
# tf.Tensor([2.57908468e+02 2.32634310e+07], shape=(2,), dtype=float64)
# 51
# tf.Tensor([2.53609994e+02 2.28553800e+07], shape=(2,), dtype=float64)
# 52
# tf.Tensor([2.5082688e+02 2.1283869e+07], shape=(2,), dtype=float64)
# 53
# tf.Tensor([2.5562057e+02 2.4126700e+07], shape=(2,), dtype=float64)
# 54
# tf.Tensor([2.56046456e+02 2.03199110e+07], shape=(2,), dtype=float64)
# 55
# tf.Tensor([2.61929622e+02 2.20931900e+07], shape=(2,), dtype=float64)
# 56
# tf.Tensor([2.64098667e+02 1.87476900e+07], shape=(2,), dtype=float64)
# 57
# tf.Tensor([2.49578936e+02 3.33533180e+07], shape=(2,), dtype=float64)
# 58
# tf.Tensor([2.49806735e+02 2.39129540e+07], shape=(2,), dtype=float64)
# 59
# tf.Tensor([2.43032181e+02 3.15309480e+07], shape=(2,), dtype=float64)
# 60
# tf.Tensor([2.42398304e+02 3.97917680e+07], shape=(2,), dtype=float64)
# 61
# tf.Tensor([2.42180409e+02 2.68269310e+07], shape=(2,), dtype=float64)
# 62
# tf.Tensor([2.40130215e+02 2.66602990e+07], shape=(2,), dtype=float64)
# 63
# tf.Tensor([2.36663704e+02 2.86255570e+07], shape=(2,), dtype=float64)
# 64
# tf.Tensor([2.3867428e+02 3.0927092e+07], shape=(2,), dtype=float64)
# 65
# tf.Tensor([2.35643559e+02 3.41760480e+07], shape=(2,), dtype=float64)
# 66
# tf.Tensor([2.35178056e+02 2.76941900e+07], shape=(2,), dtype=float64)
# 67
# tf.Tensor([2.34148007e+02 2.70187320e+07], shape=(2,), dtype=float64)
# 68
# tf.Tensor([2.38763419e+02 2.90296790e+07], shape=(2,), dtype=float64)
# 69
# tf.Tensor([2.35227577e+02 2.74842330e+07], shape=(2,), dtype=float64)
# 70
# tf.Tensor([2.30671591e+02 3.56948320e+07], shape=(2,), dtype=float64)
# 71
# tf.Tensor([2.38436577e+02 2.88803570e+07], shape=(2,), dtype=float64)
# 72
# tf.Tensor([2.46498692e+02 3.48884160e+07], shape=(2,), dtype=float64)
# 73
# tf.Tensor([2.46815631e+02 2.03471360e+07], shape=(2,), dtype=float64)
# 74
# tf.Tensor([2.4442869e+02 2.0239886e+07], shape=(2,), dtype=float64)
# 75
# tf.Tensor([2.31998769e+02 3.77696020e+07], shape=(2,), dtype=float64)
# 76
# tf.Tensor([2.27056514e+02 2.97436080e+07], shape=(2,), dtype=float64)
# 77
# tf.Tensor([2.23253256e+02 3.04739540e+07], shape=(2,), dtype=float64)
# 78
# tf.Tensor([2.23590002e+02 2.19039370e+07], shape=(2,), dtype=float64)
# 79
# tf.Tensor([2.31998769e+02 4.25518180e+07], shape=(2,), dtype=float64)
# 80
# tf.Tensor([2.26373116e+02 3.01985880e+07], shape=(2,), dtype=float64)
# 81
# tf.Tensor([2.3525729e+02 2.8142268e+07], shape=(2,), dtype=float64)
# 82
# tf.Tensor([2.36218009e+02 2.63295910e+07], shape=(2,), dtype=float64)
# 83
# tf.Tensor([2.34217337e+02 1.99856980e+07], shape=(2,), dtype=float64)
# 84
# tf.Tensor([2.33890494e+02 2.18110150e+07], shape=(2,), dtype=float64)
# 85
# tf.Tensor([2.39803373e+02 2.62997330e+07], shape=(2,), dtype=float64)
# 86
# tf.Tensor([2.44884288e+02 2.49112120e+07], shape=(2,), dtype=float64)
# 87
# tf.Tensor([2.48261661e+02 3.47755050e+07], shape=(2,), dtype=float64)
# 88
# tf.Tensor([2.29106708e+02 8.26848460e+07], shape=(2,), dtype=float64)
# 89
# tf.Tensor([2.24580434e+02 4.04246450e+07], shape=(2,), dtype=float64)
# 90
# tf.Tensor([2.33613173e+02 4.06477240e+07], shape=(2,), dtype=float64)
# 91
# tf.Tensor([2.29908958e+02 2.83572650e+07], shape=(2,), dtype=float64)
# 92
# tf.Tensor([2.25986848e+02 3.05922710e+07], shape=(2,), dtype=float64)
# 93
# tf.Tensor([2.17994062e+02 3.84070080e+07], shape=(2,), dtype=float64)
# 94
# tf.Tensor([2.12200036e+02 3.66339220e+07], shape=(2,), dtype=float64)
# 95
# tf.Tensor([2.19271719e+02 3.67890630e+07], shape=(2,), dtype=float64)
# 96
# tf.Tensor([2.25689718e+02 3.34979790e+07], shape=(2,), dtype=float64)
# 97
# tf.Tensor([2.2668015e+02 2.8192548e+07], shape=(2,), dtype=float64)
# 98
# tf.Tensor([2.22361867e+02 2.78529100e+07], shape=(2,), dtype=float64)
# 99
# tf.Tensor([2.40655144e+02 4.62680210e+07], shape=(2,), dtype=float64)
# 100
# tf.Tensor([2.44745628e+02 3.46202460e+07], shape=(2,), dtype=float64)
# 101
# tf.Tensor([2.39238827e+02 3.11233400e+07], shape=(2,), dtype=float64)
# 102
# tf.Tensor([2.39654808e+02 3.13901170e+07], shape=(2,), dtype=float64)
# 103
# tf.Tensor([2.40090598e+02 2.40932720e+07], shape=(2,), dtype=float64)
# 104
# tf.Tensor([2.40040937e+02 2.31235440e+07], shape=(2,), dtype=float64)
# 105
# tf.Tensor([2.39584057e+02 2.76135230e+07], shape=(2,), dtype=float64)
# 106
# tf.Tensor([2.40408428e+02 2.63947000e+07], shape=(2,), dtype=float64)
# 107
# tf.Tensor([2.43368218e+02 1.96656990e+07], shape=(2,), dtype=float64)
# 108
# tf.Tensor([2.45900924e+02 1.95084620e+07], shape=(2,), dtype=float64)
# 109
# tf.Tensor([2.45811534e+02 9.20077200e+06], shape=(2,), dtype=float64)
# 110
# tf.Tensor([2.40120395e+02 2.48102710e+07], shape=(2,), dtype=float64)
# 111
# tf.Tensor([2.38700093e+02 1.79563130e+07], shape=(2,), dtype=float64)
# 112
# tf.Tensor([2.53409652e+02 4.75942390e+07], shape=(2,), dtype=float64)
# 113
# tf.Tensor([2.52962704e+02 2.60415240e+07], shape=(2,), dtype=float64)
# 114
# tf.Tensor([2.53290466e+02 2.15285200e+07], shape=(2,), dtype=float64)
# 115
# tf.Tensor([2.48503155e+02 2.34352940e+07], shape=(2,), dtype=float64)
# 116
# tf.Tensor([2.43457607e+02 2.24637270e+07], shape=(2,), dtype=float64)
# 117
# tf.Tensor([2.42712694e+02 2.04815220e+07], shape=(2,), dtype=float64)
# 118
# tf.Tensor([2.45722144e+02 2.26117570e+07], shape=(2,), dtype=float64)
# 119
# tf.Tensor([2.43755573e+02 2.06097430e+07], shape=(2,), dtype=float64)
# 120
# tf.Tensor([2.50797489e+02 3.06650690e+07], shape=(2,), dtype=float64)
# 121
# tf.Tensor([2.5517758e+02 4.2196884e+07], shape=(2,), dtype=float64)
# 122
# tf.Tensor([2.55475546e+02 3.54109330e+07], shape=(2,), dtype=float64)
# 123
# tf.Tensor([2.47321225e+02 3.55680930e+07], shape=(2,), dtype=float64)
# 124
# tf.Tensor([2.43030523e+02 8.61019940e+07], shape=(2,), dtype=float64)
# 125
# tf.Tensor([2.38819279e+02 2.96964360e+07], shape=(2,), dtype=float64)
# 126
# tf.Tensor([2.40160123e+02 2.51508020e+07], shape=(2,), dtype=float64)
# 127
# tf.Tensor([2.42772287e+02 2.36906070e+07], shape=(2,), dtype=float64)
# 128
# tf.Tensor([2.36574606e+02 2.86516640e+07], shape=(2,), dtype=float64)
# 129
# tf.Tensor([2.37110944e+02 2.12069820e+07], shape=(2,), dtype=float64)
# 130
# tf.Tensor([2.35352948e+02 1.66886480e+07], shape=(2,), dtype=float64)
# 131
# tf.Tensor([2.32939428e+02 1.74571040e+07], shape=(2,), dtype=float64)
# 132
# tf.Tensor([2.39375481e+02 1.97706930e+07], shape=(2,), dtype=float64)
# 133
# tf.Tensor([2.38193552e+02 2.19384720e+07], shape=(2,), dtype=float64)
# 134
# tf.Tensor([2.37955179e+02 2.57400360e+07], shape=(2,), dtype=float64)
# 135
# tf.Tensor([2.27546254e+02 5.06233940e+07], shape=(2,), dtype=float64)
# 136
# tf.Tensor([2.20802304e+02 3.95856230e+07], shape=(2,), dtype=float64)
# 137
# tf.Tensor([2.23404535e+02 4.36135740e+07], shape=(2,), dtype=float64)
# 138
# tf.Tensor([2.25579682e+02 2.73697840e+07], shape=(2,), dtype=float64)
# 139
# tf.Tensor([2.2729795e+02 2.7033881e+07], shape=(2,), dtype=float64)
# 140
# tf.Tensor([2.34171018e+02 2.86693310e+07], shape=(2,), dtype=float64)
# 141
# tf.Tensor([2.36892436e+02 2.72694860e+07], shape=(2,), dtype=float64)
# 142
# tf.Tensor([2.37607553e+02 2.13332650e+07], shape=(2,), dtype=float64)
# 143
# tf.Tensor([2.38719957e+02 2.98312570e+07], shape=(2,), dtype=float64)
# 144
# tf.Tensor([2.34210747e+02 3.00286920e+07], shape=(2,), dtype=float64)
# 145
# tf.Tensor([2.30357061e+02 2.86230330e+07], shape=(2,), dtype=float64)
# 146
# tf.Tensor([2.38590839e+02 3.53898090e+07], shape=(2,), dtype=float64)
# 147
# tf.Tensor([2.40934833e+02 3.19339510e+07], shape=(2,), dtype=float64)
# 148
# tf.Tensor([2.40398496e+02 4.02344440e+07], shape=(2,), dtype=float64)
# 149
# tf.Tensor([2.38978194e+02 6.65266410e+07], shape=(2,), dtype=float64)
# 150
# tf.Tensor([2.46318075e+02 3.34544910e+07], shape=(2,), dtype=float64)
# 151
# tf.Tensor([2.4647699e+02 2.6498939e+07], shape=(2,), dtype=float64)
# 152
# tf.Tensor([2.41063952e+02 2.58673650e+07], shape=(2,), dtype=float64)
# 153
# tf.Tensor([2.46129364e+02 2.65410720e+07], shape=(2,), dtype=float64)
# 154
# tf.Tensor([2.51035861e+02 3.12599120e+07], shape=(2,), dtype=float64)
# 155
# tf.Tensor([2.62805495e+02 3.99404370e+07], shape=(2,), dtype=float64)
# 156
# tf.Tensor([2.56597882e+02 2.90772560e+07], shape=(2,), dtype=float64)
# 157
# tf.Tensor([2.55028597e+02 2.25179970e+07], shape=(2,), dtype=float64)
# 158
# tf.Tensor([2.6574542e+02 5.0841365e+07], shape=(2,), dtype=float64)
# 159
# tf.Tensor([2.64921049e+02 5.46860490e+07], shape=(2,), dtype=float64)
# 160
# tf.Tensor([2.61832141e+02 4.23751020e+07], shape=(2,), dtype=float64)
# 161
# tf.Tensor([2.61315668e+02 2.58184890e+07], shape=(2,), dtype=float64)
# 162
# tf.Tensor([2.6947992e+02 4.4630921e+07], shape=(2,), dtype=float64)
# 163
# tf.Tensor([2.70324155e+02 3.70479240e+07], shape=(2,), dtype=float64)
# 164
# tf.Tensor([2.68168872e+02 2.89621630e+07], shape=(2,), dtype=float64)
# 165
# tf.Tensor([2.61029518e+02 2.96036160e+07], shape=(2,), dtype=float64)
# 166
# tf.Tensor([2.5695700e+02 3.0000055e+07], shape=(2,), dtype=float64)
# 167
# tf.Tensor([2.51590038e+02 2.83974440e+07], shape=(2,), dtype=float64)
# 168
# tf.Tensor([2.50434996e+02 2.24910560e+07], shape=(2,), dtype=float64)
# 169
# tf.Tensor([2.53681062e+02 2.92190950e+07], shape=(2,), dtype=float64)
# 170
# tf.Tensor([2.48154784e+02 2.49909050e+07], shape=(2,), dtype=float64)
# 171
# tf.Tensor([2.49090766e+02 2.11900420e+07], shape=(2,), dtype=float64)
# 172
# tf.Tensor([2.48353929e+02 2.24909500e+07], shape=(2,), dtype=float64)
# 173
# tf.Tensor([2.45217392e+02 2.75652590e+07], shape=(2,), dtype=float64)
# 174
# tf.Tensor([2.50036705e+02 2.48336460e+07], shape=(2,), dtype=float64)
# 175
# tf.Tensor([2.54198839e+02 3.07601360e+07], shape=(2,), dtype=float64)
# 176
# tf.Tensor([2.55772086e+02 2.41098490e+07], shape=(2,), dtype=float64)
# 177
# tf.Tensor([2.53063712e+02 2.14731790e+07], shape=(2,), dtype=float64)
# 178
# tf.Tensor([2.52615635e+02 1.73402170e+07], shape=(2,), dtype=float64)
# 179
# tf.Tensor([2.51241534e+02 2.66533870e+07], shape=(2,), dtype=float64)
# 180
# tf.Tensor([2.47527476e+02 2.83339300e+07], shape=(2,), dtype=float64)
# 181
# tf.Tensor([2.52834695e+02 3.33397210e+07], shape=(2,), dtype=float64)
# 182
# tf.Tensor([2.59675331e+02 3.36202930e+07], shape=(2,), dtype=float64)
# 183
# tf.Tensor([2.64305456e+02 4.60280470e+07], shape=(2,), dtype=float64)
# 184
# tf.Tensor([2.75019466e+02 5.48321400e+07], shape=(2,), dtype=float64)
# 185
# tf.Tensor([2.7823566e+02 6.9527371e+07], shape=(2,), dtype=float64)
# 186
# tf.Tensor([2.71066434e+02 4.34666490e+07], shape=(2,), dtype=float64)
# 187
# tf.Tensor([2.72609809e+02 3.45587040e+07], shape=(2,), dtype=float64)
# 188
# tf.Tensor([2.71126178e+02 3.48733300e+07], shape=(2,), dtype=float64)
# 189
# tf.Tensor([2.76473225e+02 3.66108790e+07], shape=(2,), dtype=float64)
# 190
# tf.Tensor([2.79370787e+02 2.81999620e+07], shape=(2,), dtype=float64)
# 191
# tf.Tensor([2.75198696e+02 2.68402120e+07], shape=(2,), dtype=float64)
# 192
# tf.Tensor([2.74053612e+02 2.18786470e+07], shape=(2,), dtype=float64)
# 193
# tf.Tensor([2.79311044e+02 2.50870320e+07], shape=(2,), dtype=float64)
# 194
# tf.Tensor([2.82835913e+02 2.50534100e+07], shape=(2,), dtype=float64)
# 195
# tf.Tensor([2.87067748e+02 3.27659760e+07], shape=(2,), dtype=float64)
# 196
# tf.Tensor([2.86002321e+02 2.48833420e+07], shape=(2,), dtype=float64)
# 197
# tf.Tensor([2.85952535e+02 2.58242990e+07], shape=(2,), dtype=float64)
# 198
# tf.Tensor([2.83124674e+02 2.20647700e+07], shape=(2,), dtype=float64)
# 199
# tf.Tensor([2.90353643e+02 2.97703340e+07], shape=(2,), dtype=float64)
# 200
# tf.Tensor([2.88153089e+02 2.31029940e+07], shape=(2,), dtype=float64)
# 201
# tf.Tensor([2.81621128e+02 2.72765890e+07], shape=(2,), dtype=float64)
# 202
# tf.Tensor([2.82278307e+02 2.74034320e+07], shape=(2,), dtype=float64)
# 203
# tf.Tensor([2.88601166e+02 2.42226780e+07], shape=(2,), dtype=float64)
# 204
# tf.Tensor([2.8491698e+02 2.0987917e+07], shape=(2,), dtype=float64)
# 205
# tf.Tensor([2.87565611e+02 2.37911510e+07], shape=(2,), dtype=float64)
# 206
# tf.Tensor([2.87137449e+02 2.01618450e+07], shape=(2,), dtype=float64)
# 207
# tf.Tensor([2.87217107e+02 1.71502710e+07], shape=(2,), dtype=float64)
# 208
# tf.Tensor([2.84887108e+02 2.32443630e+07], shape=(2,), dtype=float64)
# 209
# tf.Tensor([2.84538604e+02 2.16763870e+07], shape=(2,), dtype=float64)
# 210
# tf.Tensor([2.80565658e+02 2.66110140e+07], shape=(2,), dtype=float64)
# 211
# tf.Tensor([2.7424280e+02 4.5772236e+07], shape=(2,), dtype=float64)
# 212
# tf.Tensor([2.94107529e+02 6.44811170e+07], shape=(2,), dtype=float64)
# 213
# tf.Tensor([3.03527095e+02 4.64626380e+07], shape=(2,), dtype=float64)
# 214
# tf.Tensor([3.05946709e+02 3.64696130e+07], shape=(2,), dtype=float64)
# 215
# tf.Tensor([3.04253975e+02 2.12941150e+07], shape=(2,), dtype=float64)
# 216
# tf.Tensor([3.04104616e+02 2.64044310e+07], shape=(2,), dtype=float64)
# 217
# tf.Tensor([3.03098933e+02 2.23607540e+07], shape=(2,), dtype=float64)
# 218
# tf.Tensor([3.04104616e+02 2.25199070e+07], shape=(2,), dtype=float64)
# 219
# tf.Tensor([3.09322219e+02 2.81970520e+07], shape=(2,), dtype=float64)
# 220
# tf.Tensor([3.07330768e+02 2.13186130e+07], shape=(2,), dtype=float64)
# 221
# tf.Tensor([3.0568782e+02 2.1340829e+07], shape=(2,), dtype=float64)
# 222
# tf.Tensor([3.10975124e+02 3.00780440e+07], shape=(2,), dtype=float64)
# 223
# tf.Tensor([3.08784527e+02 3.16801790e+07], shape=(2,), dtype=float64)
# 224
# tf.Tensor([3.0764940e+02 1.9774696e+07], shape=(2,), dtype=float64)
# 225
# tf.Tensor([3.08137306e+02 1.63365470e+07], shape=(2,), dtype=float64)
# 226
# tf.Tensor([3.10407561e+02 2.67303470e+07], shape=(2,), dtype=float64)
# 227
# tf.Tensor([3.13334994e+02 2.43150120e+07], shape=(2,), dtype=float64)
# 228
# tf.Tensor([3.17845422e+02 2.72759910e+07], shape=(2,), dtype=float64)
# 229
# tf.Tensor([3.17665803e+02 2.75467010e+07], shape=(2,), dtype=float64)
# 230
# tf.Tensor([3.20499788e+02 2.41156640e+07], shape=(2,), dtype=float64)
# 231
# tf.Tensor([3.14592326e+02 3.07971730e+07], shape=(2,), dtype=float64)
# 232
# tf.Tensor([3.13185312e+02 2.33848870e+07], shape=(2,), dtype=float64)
# 233
# tf.Tensor([3.2522975e+02 4.3301743e+07], shape=(2,), dtype=float64)
# 234
# tf.Tensor([3.32184988e+02 3.66306330e+07], shape=(2,), dtype=float64)
# 235
# tf.Tensor([3.30508546e+02 2.95030700e+07], shape=(2,), dtype=float64)
# 236
# tf.Tensor([3.27694519e+02 4.55468580e+07], shape=(2,), dtype=float64)
# 237
# tf.Tensor([3.31875645e+02 2.67738510e+07], shape=(2,), dtype=float64)
# 238
# tf.Tensor([3.34689672e+02 2.58737690e+07], shape=(2,), dtype=float64)
# 239
# tf.Tensor([3.35228529e+02 2.13070530e+07], shape=(2,), dtype=float64)
# 240
# tf.Tensor([3.32973315e+02 2.03962230e+07], shape=(2,), dtype=float64)
# 241
# tf.Tensor([3.22695129e+02 4.07171290e+07], shape=(2,), dtype=float64)
# 242
# tf.Tensor([3.24571147e+02 2.32777080e+07], shape=(2,), dtype=float64)
# 243
# tf.Tensor([3.26097907e+02 2.25289500e+07], shape=(2,), dtype=float64)
# 244
# tf.Tensor([3.31147191e+02 2.43067530e+07], shape=(2,), dtype=float64)
# 245
# tf.Tensor([3.33582023e+02 2.29512790e+07], shape=(2,), dtype=float64)
# 246
# tf.Tensor([3.36625564e+02 2.60037910e+07], shape=(2,), dtype=float64)
# 247
# tf.Tensor([3.47362776e+02 3.88990750e+07], shape=(2,), dtype=float64)
# 248
# tf.Tensor([3.41604996e+02 4.65519850e+07], shape=(2,), dtype=float64)
# 249
# tf.Tensor([3.3733406e+02 2.6375407e+07], shape=(2,), dtype=float64)
# 250
# tf.Tensor([3.32853569e+02 2.51177990e+07], shape=(2,), dtype=float64)
# 251
# tf.Tensor([3.38990544e+02 2.35567640e+07], shape=(2,), dtype=float64)
# 252
# tf.Tensor([3.34310477e+02 2.31469010e+07], shape=(2,), dtype=float64)
# 253
# tf.Tensor([3.27904074e+02 2.15205820e+07], shape=(2,), dtype=float64)
# 254
# tf.Tensor([3.3386143e+02 2.4354110e+07], shape=(2,), dtype=float64)
# 255
# tf.Tensor([3.35138719e+02 2.02595230e+07], shape=(2,), dtype=float64)
# 256
# tf.Tensor([3.34340414e+02 1.69970420e+07], shape=(2,), dtype=float64)
# 257
# tf.Tensor([3.39818787e+02 2.68327560e+07], shape=(2,), dtype=float64)
# 258
# tf.Tensor([3.37274187e+02 1.25086920e+07], shape=(2,), dtype=float64)
# 259
# tf.Tensor([3.37433848e+02 1.81723780e+07], shape=(2,), dtype=float64)
# 260
# tf.Tensor([3.40547241e+02 2.81955340e+07], shape=(2,), dtype=float64)
# 261
# tf.Tensor([3.36505818e+02 2.12148240e+07], shape=(2,), dtype=float64)
# 262
# tf.Tensor([3.31127233e+02 3.27914490e+07], shape=(2,), dtype=float64)
# 263
# tf.Tensor([3.31765878e+02 2.66982180e+07], shape=(2,), dtype=float64)
# 264
# tf.Tensor([3.3648586e+02 2.9995262e+07], shape=(2,), dtype=float64)
# 265
# tf.Tensor([3.41934297e+02 2.05671590e+07], shape=(2,), dtype=float64)
# 266
# tf.Tensor([3.44508833e+02 2.83527290e+07], shape=(2,), dtype=float64)
# 267
# tf.Tensor([3.44997795e+02 2.03639270e+07], shape=(2,), dtype=float64)
# 268
# tf.Tensor([3.58728653e+02 6.48727050e+07], shape=(2,), dtype=float64)
# 269
# tf.Tensor([3.54327993e+02 3.97329010e+07], shape=(2,), dtype=float64)
# 270
# tf.Tensor([3.46135381e+02 3.37783950e+07], shape=(2,), dtype=float64)
# 271
# tf.Tensor([3.43041946e+02 6.94053820e+07], shape=(2,), dtype=float64)
# 272
# tf.Tensor([3.44379108e+02 2.67192070e+07], shape=(2,), dtype=float64)
# 273
# tf.Tensor([3.50236676e+02 4.16377390e+07], shape=(2,), dtype=float64)
# 274
# tf.Tensor([3.37054653e+02 5.83837020e+07], shape=(2,), dtype=float64)
# 275
# tf.Tensor([3.30019584e+02 3.96352620e+07], shape=(2,), dtype=float64)
# 276
# tf.Tensor([3.37653382e+02 2.84848680e+07], shape=(2,), dtype=float64)
# 277
# tf.Tensor([3.35208571e+02 2.54460220e+07], shape=(2,), dtype=float64)
# 278
# tf.Tensor([3.35627682e+02 1.83812530e+07], shape=(2,), dtype=float64)
# 279
# tf.Tensor([3.26806403e+02 2.77612570e+07], shape=(2,), dtype=float64)
# 280
# tf.Tensor([3.25968182e+02 1.83603520e+07], shape=(2,), dtype=float64)
# 281
# tf.Tensor([3.2708581e+02 2.3741484e+07], shape=(2,), dtype=float64)
# 282
# tf.Tensor([3.29410876e+02 1.77415260e+07], shape=(2,), dtype=float64)
# 283
# tf.Tensor([3.25359474e+02 2.23275740e+07], shape=(2,), dtype=float64)
# 284
# tf.Tensor([3.21547564e+02 2.23732680e+07], shape=(2,), dtype=float64)
# 285
# tf.Tensor([3.22246082e+02 2.01137250e+07], shape=(2,), dtype=float64)
# 286
# tf.Tensor([3.20330148e+02 2.43554910e+07], shape=(2,), dtype=float64)
# 287
# tf.Tensor([3.23353731e+02 1.88361390e+07], shape=(2,), dtype=float64)
# 288
# tf.Tensor([3.21178348e+02 1.69662850e+07], shape=(2,), dtype=float64)
# 289
# tf.Tensor([3.2040000e+02 2.0698864e+07], shape=(2,), dtype=float64)
# 290
# tf.Tensor([3.1688000e+02 2.1257161e+07], shape=(2,), dtype=float64)
# 291
# tf.Tensor([3.1648000e+02 2.4755012e+07], shape=(2,), dtype=float64)
# 292
# tf.Tensor([3.2188000e+02 2.4039956e+07], shape=(2,), dtype=float64)
# 293
# tf.Tensor([3.2246000e+02 1.6102024e+07], shape=(2,), dtype=float64)
# 294
# tf.Tensor([3.2700000e+02 2.1166382e+07], shape=(2,), dtype=float64)
# 295
# tf.Tensor([3.1997000e+02 2.3281434e+07], shape=(2,), dtype=float64)
# 296
# tf.Tensor([3.2298000e+02 2.1684104e+07], shape=(2,), dtype=float64)
# 297
# tf.Tensor([3.2370000e+02 1.4808482e+07], shape=(2,), dtype=float64)
# 298
# tf.Tensor([3.284100e+02 1.928459e+07], shape=(2,), dtype=float64)
# 299
# ----------------------------------------------------------------------------------------------------
# --------------------------------Batch to window size--------------------------------
# 0 tf.Tensor(
# [[2.50778474e+02 2.99282970e+07]
#  [2.50175593e+02 2.59612150e+07]
#  [2.55838716e+02 2.58614490e+07]
#  [2.64575540e+02 3.39232310e+07]
#  [2.61798337e+02 2.46151140e+07]
#  [2.53486494e+02 2.73802470e+07]
#  [2.57222376e+02 2.00698390e+07]
#  [2.53832409e+02 3.17308680e+07]
#  [2.56550312e+02 2.28376920e+07]
#  [2.59782146e+02 2.29716340e+07]
#  [2.63102930e+02 2.38244190e+07]
#  [2.65267370e+02 2.08598740e+07]
#  [2.64536006e+02 1.96587510e+07]
#  [2.61422772e+02 1.95191080e+07]
#  [2.50709291e+02 3.58684500e+07]
#  [2.49770379e+02 2.94974230e+07]
#  [2.51114505e+02 2.51028230e+07]
#  [2.53723693e+02 2.97740500e+07]
#  [2.51282521e+02 2.09750340e+07]
#  [2.56500896e+02 2.50125620e+07]], shape=(20, 2), dtype=float64)
# 1 tf.Tensor(
# [[2.59208916e+02 2.27882820e+07]
#  [2.61748920e+02 2.24046750e+07]
#  [2.57321208e+02 2.18812900e+07]
#  [2.55809066e+02 2.10559980e+07]
#  [2.48959949e+02 3.93479570e+07]
#  [2.65603401e+02 4.59940490e+07]
#  [2.73183881e+02 3.34593270e+07]
#  [2.77463343e+02 3.21527520e+07]
#  [2.74765206e+02 2.15395800e+07]
#  [2.71612439e+02 2.27541840e+07]
#  [2.79173152e+02 2.35188740e+07]
#  [2.80339379e+02 1.80986680e+07]
#  [2.79608016e+02 1.67746060e+07]
#  [2.77048245e+02 1.87578180e+07]
#  [2.79005136e+02 2.34052380e+07]
#  [2.85785069e+02 2.46878450e+07]
#  [2.83670046e+02 2.00659380e+07]
#  [2.88502973e+02 2.26196750e+07]
#  [2.90044765e+02 1.80856540e+07]
#  [2.89293635e+02 1.81028820e+07]], shape=(20, 2), dtype=float64)
# 2 tf.Tensor(
# [[2.88532622e+02 1.82533580e+07]
#  [2.87393626e+02 1.71861920e+07]
#  [2.83412090e+02 2.05700330e+07]
#  [2.75092462e+02 2.50610700e+07]
#  [2.73794996e+02 1.75274090e+07]
#  [2.73151215e+02 1.81370190e+07]
#  [2.76181937e+02 1.65834070e+07]
#  [2.65524889e+02 2.75493070e+07]
#  [2.62692254e+02 2.01213710e+07]
#  [2.60453878e+02 2.27670710e+07]
#  [2.58968230e+02 2.47918340e+07]
#  [2.57908468e+02 2.32634310e+07]
#  [2.53609994e+02 2.28553800e+07]
#  [2.50826880e+02 2.12838690e+07]
#  [2.55620570e+02 2.41267000e+07]
#  [2.56046456e+02 2.03199110e+07]
#  [2.61929622e+02 2.20931900e+07]
#  [2.64098667e+02 1.87476900e+07]
#  [2.49578936e+02 3.33533180e+07]
#  [2.49806735e+02 2.39129540e+07]], shape=(20, 2), dtype=float64)
# 3 tf.Tensor(
# [[2.43032181e+02 3.15309480e+07]
#  [2.42398304e+02 3.97917680e+07]
#  [2.42180409e+02 2.68269310e+07]
#  [2.40130215e+02 2.66602990e+07]
#  [2.36663704e+02 2.86255570e+07]
#  [2.38674280e+02 3.09270920e+07]
#  [2.35643559e+02 3.41760480e+07]
#  [2.35178056e+02 2.76941900e+07]
#  [2.34148007e+02 2.70187320e+07]
#  [2.38763419e+02 2.90296790e+07]
#  [2.35227577e+02 2.74842330e+07]
#  [2.30671591e+02 3.56948320e+07]
#  [2.38436577e+02 2.88803570e+07]
#  [2.46498692e+02 3.48884160e+07]
#  [2.46815631e+02 2.03471360e+07]
#  [2.44428690e+02 2.02398860e+07]
#  [2.31998769e+02 3.77696020e+07]
#  [2.27056514e+02 2.97436080e+07]
#  [2.23253256e+02 3.04739540e+07]
#  [2.23590002e+02 2.19039370e+07]], shape=(20, 2), dtype=float64)
# 4 tf.Tensor(
# [[2.31998769e+02 4.25518180e+07]
#  [2.26373116e+02 3.01985880e+07]
#  [2.35257290e+02 2.81422680e+07]
#  [2.36218009e+02 2.63295910e+07]
#  [2.34217337e+02 1.99856980e+07]
#  [2.33890494e+02 2.18110150e+07]
#  [2.39803373e+02 2.62997330e+07]
#  [2.44884288e+02 2.49112120e+07]
#  [2.48261661e+02 3.47755050e+07]
#  [2.29106708e+02 8.26848460e+07]
#  [2.24580434e+02 4.04246450e+07]
#  [2.33613173e+02 4.06477240e+07]
#  [2.29908958e+02 2.83572650e+07]
#  [2.25986848e+02 3.05922710e+07]
#  [2.17994062e+02 3.84070080e+07]
#  [2.12200036e+02 3.66339220e+07]
#  [2.19271719e+02 3.67890630e+07]
#  [2.25689718e+02 3.34979790e+07]
#  [2.26680150e+02 2.81925480e+07]
#  [2.22361867e+02 2.78529100e+07]], shape=(20, 2), dtype=float64)
# 5 tf.Tensor(
# [[2.40655144e+02 4.62680210e+07]
#  [2.44745628e+02 3.46202460e+07]
#  [2.39238827e+02 3.11233400e+07]
#  [2.39654808e+02 3.13901170e+07]
#  [2.40090598e+02 2.40932720e+07]
#  [2.40040937e+02 2.31235440e+07]
#  [2.39584057e+02 2.76135230e+07]
#  [2.40408428e+02 2.63947000e+07]
#  [2.43368218e+02 1.96656990e+07]
#  [2.45900924e+02 1.95084620e+07]
#  [2.45811534e+02 9.20077200e+06]
#  [2.40120395e+02 2.48102710e+07]
#  [2.38700093e+02 1.79563130e+07]
#  [2.53409652e+02 4.75942390e+07]
#  [2.52962704e+02 2.60415240e+07]
#  [2.53290466e+02 2.15285200e+07]
#  [2.48503155e+02 2.34352940e+07]
#  [2.43457607e+02 2.24637270e+07]
#  [2.42712694e+02 2.04815220e+07]
#  [2.45722144e+02 2.26117570e+07]], shape=(20, 2), dtype=float64)
# 6 tf.Tensor(
# [[2.43755573e+02 2.06097430e+07]
#  [2.50797489e+02 3.06650690e+07]
#  [2.55177580e+02 4.21968840e+07]
#  [2.55475546e+02 3.54109330e+07]
#  [2.47321225e+02 3.55680930e+07]
#  [2.43030523e+02 8.61019940e+07]
#  [2.38819279e+02 2.96964360e+07]
#  [2.40160123e+02 2.51508020e+07]
#  [2.42772287e+02 2.36906070e+07]
#  [2.36574606e+02 2.86516640e+07]
#  [2.37110944e+02 2.12069820e+07]
#  [2.35352948e+02 1.66886480e+07]
#  [2.32939428e+02 1.74571040e+07]
#  [2.39375481e+02 1.97706930e+07]
#  [2.38193552e+02 2.19384720e+07]
#  [2.37955179e+02 2.57400360e+07]
#  [2.27546254e+02 5.06233940e+07]
#  [2.20802304e+02 3.95856230e+07]
#  [2.23404535e+02 4.36135740e+07]
#  [2.25579682e+02 2.73697840e+07]], shape=(20, 2), dtype=float64)
# 7 tf.Tensor(
# [[2.27297950e+02 2.70338810e+07]
#  [2.34171018e+02 2.86693310e+07]
#  [2.36892436e+02 2.72694860e+07]
#  [2.37607553e+02 2.13332650e+07]
#  [2.38719957e+02 2.98312570e+07]
#  [2.34210747e+02 3.00286920e+07]
#  [2.30357061e+02 2.86230330e+07]
#  [2.38590839e+02 3.53898090e+07]
#  [2.40934833e+02 3.19339510e+07]
#  [2.40398496e+02 4.02344440e+07]
#  [2.38978194e+02 6.65266410e+07]
#  [2.46318075e+02 3.34544910e+07]
#  [2.46476990e+02 2.64989390e+07]
#  [2.41063952e+02 2.58673650e+07]
#  [2.46129364e+02 2.65410720e+07]
#  [2.51035861e+02 3.12599120e+07]
#  [2.62805495e+02 3.99404370e+07]
#  [2.56597882e+02 2.90772560e+07]
#  [2.55028597e+02 2.25179970e+07]
#  [2.65745420e+02 5.08413650e+07]], shape=(20, 2), dtype=float64)
# 8 tf.Tensor(
# [[2.64921049e+02 5.46860490e+07]
#  [2.61832141e+02 4.23751020e+07]
#  [2.61315668e+02 2.58184890e+07]
#  [2.69479920e+02 4.46309210e+07]
#  [2.70324155e+02 3.70479240e+07]
#  [2.68168872e+02 2.89621630e+07]
#  [2.61029518e+02 2.96036160e+07]
#  [2.56957000e+02 3.00000550e+07]
#  [2.51590038e+02 2.83974440e+07]
#  [2.50434996e+02 2.24910560e+07]
#  [2.53681062e+02 2.92190950e+07]
#  [2.48154784e+02 2.49909050e+07]
#  [2.49090766e+02 2.11900420e+07]
#  [2.48353929e+02 2.24909500e+07]
#  [2.45217392e+02 2.75652590e+07]
#  [2.50036705e+02 2.48336460e+07]
#  [2.54198839e+02 3.07601360e+07]
#  [2.55772086e+02 2.41098490e+07]
#  [2.53063712e+02 2.14731790e+07]
#  [2.52615635e+02 1.73402170e+07]], shape=(20, 2), dtype=float64)
# 9 tf.Tensor(
# [[2.51241534e+02 2.66533870e+07]
#  [2.47527476e+02 2.83339300e+07]
#  [2.52834695e+02 3.33397210e+07]
#  [2.59675331e+02 3.36202930e+07]
#  [2.64305456e+02 4.60280470e+07]
#  [2.75019466e+02 5.48321400e+07]
#  [2.78235660e+02 6.95273710e+07]
#  [2.71066434e+02 4.34666490e+07]
#  [2.72609809e+02 3.45587040e+07]
#  [2.71126178e+02 3.48733300e+07]
#  [2.76473225e+02 3.66108790e+07]
#  [2.79370787e+02 2.81999620e+07]
#  [2.75198696e+02 2.68402120e+07]
#  [2.74053612e+02 2.18786470e+07]
#  [2.79311044e+02 2.50870320e+07]
#  [2.82835913e+02 2.50534100e+07]
#  [2.87067748e+02 3.27659760e+07]
#  [2.86002321e+02 2.48833420e+07]
#  [2.85952535e+02 2.58242990e+07]
#  [2.83124674e+02 2.20647700e+07]], shape=(20, 2), dtype=float64)
# 10 tf.Tensor(
# [[2.90353643e+02 2.97703340e+07]
#  [2.88153089e+02 2.31029940e+07]
#  [2.81621128e+02 2.72765890e+07]
#  [2.82278307e+02 2.74034320e+07]
#  [2.88601166e+02 2.42226780e+07]
#  [2.84916980e+02 2.09879170e+07]
#  [2.87565611e+02 2.37911510e+07]
#  [2.87137449e+02 2.01618450e+07]
#  [2.87217107e+02 1.71502710e+07]
#  [2.84887108e+02 2.32443630e+07]
#  [2.84538604e+02 2.16763870e+07]
#  [2.80565658e+02 2.66110140e+07]
#  [2.74242800e+02 4.57722360e+07]
#  [2.94107529e+02 6.44811170e+07]
#  [3.03527095e+02 4.64626380e+07]
#  [3.05946709e+02 3.64696130e+07]
#  [3.04253975e+02 2.12941150e+07]
#  [3.04104616e+02 2.64044310e+07]
#  [3.03098933e+02 2.23607540e+07]
#  [3.04104616e+02 2.25199070e+07]], shape=(20, 2), dtype=float64)
# 11 tf.Tensor(
# [[3.09322219e+02 2.81970520e+07]
#  [3.07330768e+02 2.13186130e+07]
#  [3.05687820e+02 2.13408290e+07]
#  [3.10975124e+02 3.00780440e+07]
#  [3.08784527e+02 3.16801790e+07]
#  [3.07649400e+02 1.97746960e+07]
#  [3.08137306e+02 1.63365470e+07]
#  [3.10407561e+02 2.67303470e+07]
#  [3.13334994e+02 2.43150120e+07]
#  [3.17845422e+02 2.72759910e+07]
#  [3.17665803e+02 2.75467010e+07]
#  [3.20499788e+02 2.41156640e+07]
#  [3.14592326e+02 3.07971730e+07]
#  [3.13185312e+02 2.33848870e+07]
#  [3.25229750e+02 4.33017430e+07]
#  [3.32184988e+02 3.66306330e+07]
#  [3.30508546e+02 2.95030700e+07]
#  [3.27694519e+02 4.55468580e+07]
#  [3.31875645e+02 2.67738510e+07]
#  [3.34689672e+02 2.58737690e+07]], shape=(20, 2), dtype=float64)
# 12 tf.Tensor(
# [[3.35228529e+02 2.13070530e+07]
#  [3.32973315e+02 2.03962230e+07]
#  [3.22695129e+02 4.07171290e+07]
#  [3.24571147e+02 2.32777080e+07]
#  [3.26097907e+02 2.25289500e+07]
#  [3.31147191e+02 2.43067530e+07]
#  [3.33582023e+02 2.29512790e+07]
#  [3.36625564e+02 2.60037910e+07]
#  [3.47362776e+02 3.88990750e+07]
#  [3.41604996e+02 4.65519850e+07]
#  [3.37334060e+02 2.63754070e+07]
#  [3.32853569e+02 2.51177990e+07]
#  [3.38990544e+02 2.35567640e+07]
#  [3.34310477e+02 2.31469010e+07]
#  [3.27904074e+02 2.15205820e+07]
#  [3.33861430e+02 2.43541100e+07]
#  [3.35138719e+02 2.02595230e+07]
#  [3.34340414e+02 1.69970420e+07]
#  [3.39818787e+02 2.68327560e+07]
#  [3.37274187e+02 1.25086920e+07]], shape=(20, 2), dtype=float64)
# 13 tf.Tensor(
# [[3.37433848e+02 1.81723780e+07]
#  [3.40547241e+02 2.81955340e+07]
#  [3.36505818e+02 2.12148240e+07]
#  [3.31127233e+02 3.27914490e+07]
#  [3.31765878e+02 2.66982180e+07]
#  [3.36485860e+02 2.99952620e+07]
#  [3.41934297e+02 2.05671590e+07]
#  [3.44508833e+02 2.83527290e+07]
#  [3.44997795e+02 2.03639270e+07]
#  [3.58728653e+02 6.48727050e+07]
#  [3.54327993e+02 3.97329010e+07]
#  [3.46135381e+02 3.37783950e+07]
#  [3.43041946e+02 6.94053820e+07]
#  [3.44379108e+02 2.67192070e+07]
#  [3.50236676e+02 4.16377390e+07]
#  [3.37054653e+02 5.83837020e+07]
#  [3.30019584e+02 3.96352620e+07]
#  [3.37653382e+02 2.84848680e+07]
#  [3.35208571e+02 2.54460220e+07]
#  [3.35627682e+02 1.83812530e+07]], shape=(20, 2), dtype=float64)
# 14 tf.Tensor(
# [[3.26806403e+02 2.77612570e+07]
#  [3.25968182e+02 1.83603520e+07]
#  [3.27085810e+02 2.37414840e+07]
#  [3.29410876e+02 1.77415260e+07]
#  [3.25359474e+02 2.23275740e+07]
#  [3.21547564e+02 2.23732680e+07]
#  [3.22246082e+02 2.01137250e+07]
#  [3.20330148e+02 2.43554910e+07]
#  [3.23353731e+02 1.88361390e+07]
#  [3.21178348e+02 1.69662850e+07]
#  [3.20400000e+02 2.06988640e+07]
#  [3.16880000e+02 2.12571610e+07]
#  [3.16480000e+02 2.47550120e+07]
#  [3.21880000e+02 2.40399560e+07]
#  [3.22460000e+02 1.61020240e+07]
#  [3.27000000e+02 2.11663820e+07]
#  [3.19970000e+02 2.32814340e+07]
#  [3.22980000e+02 2.16841040e+07]
#  [3.23700000e+02 1.48084820e+07]
#  [3.28410000e+02 1.92845900e+07]], shape=(20, 2), dtype=float64)
# ----------------------------------------------------------------------------------------------------
# --------------------------------Batch to Batch size-----------------------------------
# tf.Tensor(
# [[[2.50778474e+02 2.99282970e+07]
#   [2.50175593e+02 2.59612150e+07]
#   [2.55838716e+02 2.58614490e+07]
#   [2.64575540e+02 3.39232310e+07]
#   [2.61798337e+02 2.46151140e+07]
#   [2.53486494e+02 2.73802470e+07]
#   [2.57222376e+02 2.00698390e+07]
#   [2.53832409e+02 3.17308680e+07]
#   [2.56550312e+02 2.28376920e+07]
#   [2.59782146e+02 2.29716340e+07]
#   [2.63102930e+02 2.38244190e+07]
#   [2.65267370e+02 2.08598740e+07]
#   [2.64536006e+02 1.96587510e+07]
#   [2.61422772e+02 1.95191080e+07]
#   [2.50709291e+02 3.58684500e+07]
#   [2.49770379e+02 2.94974230e+07]
#   [2.51114505e+02 2.51028230e+07]
#   [2.53723693e+02 2.97740500e+07]
#   [2.51282521e+02 2.09750340e+07]
#   [2.56500896e+02 2.50125620e+07]]
#
#  [[2.59208916e+02 2.27882820e+07]
#   [2.61748920e+02 2.24046750e+07]
#   [2.57321208e+02 2.18812900e+07]
#   [2.55809066e+02 2.10559980e+07]
#   [2.48959949e+02 3.93479570e+07]
#   [2.65603401e+02 4.59940490e+07]
#   [2.73183881e+02 3.34593270e+07]
#   [2.77463343e+02 3.21527520e+07]
#   [2.74765206e+02 2.15395800e+07]
#   [2.71612439e+02 2.27541840e+07]
#   [2.79173152e+02 2.35188740e+07]
#   [2.80339379e+02 1.80986680e+07]
#   [2.79608016e+02 1.67746060e+07]
#   [2.77048245e+02 1.87578180e+07]
#   [2.79005136e+02 2.34052380e+07]
#   [2.85785069e+02 2.46878450e+07]
#   [2.83670046e+02 2.00659380e+07]
#   [2.88502973e+02 2.26196750e+07]
#   [2.90044765e+02 1.80856540e+07]
#   [2.89293635e+02 1.81028820e+07]]
#
#  [[2.88532622e+02 1.82533580e+07]
#   [2.87393626e+02 1.71861920e+07]
#   [2.83412090e+02 2.05700330e+07]
#   [2.75092462e+02 2.50610700e+07]
#   [2.73794996e+02 1.75274090e+07]
#   [2.73151215e+02 1.81370190e+07]
#   [2.76181937e+02 1.65834070e+07]
#   [2.65524889e+02 2.75493070e+07]
#   [2.62692254e+02 2.01213710e+07]
#   [2.60453878e+02 2.27670710e+07]
#   [2.58968230e+02 2.47918340e+07]
#   [2.57908468e+02 2.32634310e+07]
#   [2.53609994e+02 2.28553800e+07]
#   [2.50826880e+02 2.12838690e+07]
#   [2.55620570e+02 2.41267000e+07]
#   [2.56046456e+02 2.03199110e+07]
#   [2.61929622e+02 2.20931900e+07]
#   [2.64098667e+02 1.87476900e+07]
#   [2.49578936e+02 3.33533180e+07]
#   [2.49806735e+02 2.39129540e+07]]
#
#  [[2.43032181e+02 3.15309480e+07]
#   [2.42398304e+02 3.97917680e+07]
#   [2.42180409e+02 2.68269310e+07]
#   [2.40130215e+02 2.66602990e+07]
#   [2.36663704e+02 2.86255570e+07]
#   [2.38674280e+02 3.09270920e+07]
#   [2.35643559e+02 3.41760480e+07]
#   [2.35178056e+02 2.76941900e+07]
#   [2.34148007e+02 2.70187320e+07]
#   [2.38763419e+02 2.90296790e+07]
#   [2.35227577e+02 2.74842330e+07]
#   [2.30671591e+02 3.56948320e+07]
#   [2.38436577e+02 2.88803570e+07]
#   [2.46498692e+02 3.48884160e+07]
#   [2.46815631e+02 2.03471360e+07]
#   [2.44428690e+02 2.02398860e+07]
#   [2.31998769e+02 3.77696020e+07]
#   [2.27056514e+02 2.97436080e+07]
#   [2.23253256e+02 3.04739540e+07]
#   [2.23590002e+02 2.19039370e+07]]
#
#  [[2.31998769e+02 4.25518180e+07]
#   [2.26373116e+02 3.01985880e+07]
#   [2.35257290e+02 2.81422680e+07]
#   [2.36218009e+02 2.63295910e+07]
#   [2.34217337e+02 1.99856980e+07]
#   [2.33890494e+02 2.18110150e+07]
#   [2.39803373e+02 2.62997330e+07]
#   [2.44884288e+02 2.49112120e+07]
#   [2.48261661e+02 3.47755050e+07]
#   [2.29106708e+02 8.26848460e+07]
#   [2.24580434e+02 4.04246450e+07]
#   [2.33613173e+02 4.06477240e+07]
#   [2.29908958e+02 2.83572650e+07]
#   [2.25986848e+02 3.05922710e+07]
#   [2.17994062e+02 3.84070080e+07]
#   [2.12200036e+02 3.66339220e+07]
#   [2.19271719e+02 3.67890630e+07]
#   [2.25689718e+02 3.34979790e+07]
#   [2.26680150e+02 2.81925480e+07]
#   [2.22361867e+02 2.78529100e+07]]
#
#  [[2.40655144e+02 4.62680210e+07]
#   [2.44745628e+02 3.46202460e+07]
#   [2.39238827e+02 3.11233400e+07]
#   [2.39654808e+02 3.13901170e+07]
#   [2.40090598e+02 2.40932720e+07]
#   [2.40040937e+02 2.31235440e+07]
#   [2.39584057e+02 2.76135230e+07]
#   [2.40408428e+02 2.63947000e+07]
#   [2.43368218e+02 1.96656990e+07]
#   [2.45900924e+02 1.95084620e+07]
#   [2.45811534e+02 9.20077200e+06]
#   [2.40120395e+02 2.48102710e+07]
#   [2.38700093e+02 1.79563130e+07]
#   [2.53409652e+02 4.75942390e+07]
#   [2.52962704e+02 2.60415240e+07]
#   [2.53290466e+02 2.15285200e+07]
#   [2.48503155e+02 2.34352940e+07]
#   [2.43457607e+02 2.24637270e+07]
#   [2.42712694e+02 2.04815220e+07]
#   [2.45722144e+02 2.26117570e+07]]
#
#  [[2.43755573e+02 2.06097430e+07]
#   [2.50797489e+02 3.06650690e+07]
#   [2.55177580e+02 4.21968840e+07]
#   [2.55475546e+02 3.54109330e+07]
#   [2.47321225e+02 3.55680930e+07]
#   [2.43030523e+02 8.61019940e+07]
#   [2.38819279e+02 2.96964360e+07]
#   [2.40160123e+02 2.51508020e+07]
#   [2.42772287e+02 2.36906070e+07]
#   [2.36574606e+02 2.86516640e+07]
#   [2.37110944e+02 2.12069820e+07]
#   [2.35352948e+02 1.66886480e+07]
#   [2.32939428e+02 1.74571040e+07]
#   [2.39375481e+02 1.97706930e+07]
#   [2.38193552e+02 2.19384720e+07]
#   [2.37955179e+02 2.57400360e+07]
#   [2.27546254e+02 5.06233940e+07]
#   [2.20802304e+02 3.95856230e+07]
#   [2.23404535e+02 4.36135740e+07]
#   [2.25579682e+02 2.73697840e+07]]
#
#  [[2.27297950e+02 2.70338810e+07]
#   [2.34171018e+02 2.86693310e+07]
#   [2.36892436e+02 2.72694860e+07]
#   [2.37607553e+02 2.13332650e+07]
#   [2.38719957e+02 2.98312570e+07]
#   [2.34210747e+02 3.00286920e+07]
#   [2.30357061e+02 2.86230330e+07]
#   [2.38590839e+02 3.53898090e+07]
#   [2.40934833e+02 3.19339510e+07]
#   [2.40398496e+02 4.02344440e+07]
#   [2.38978194e+02 6.65266410e+07]
#   [2.46318075e+02 3.34544910e+07]
#   [2.46476990e+02 2.64989390e+07]
#   [2.41063952e+02 2.58673650e+07]
#   [2.46129364e+02 2.65410720e+07]
#   [2.51035861e+02 3.12599120e+07]
#   [2.62805495e+02 3.99404370e+07]
#   [2.56597882e+02 2.90772560e+07]
#   [2.55028597e+02 2.25179970e+07]
#   [2.65745420e+02 5.08413650e+07]]
#
#  [[2.64921049e+02 5.46860490e+07]
#   [2.61832141e+02 4.23751020e+07]
#   [2.61315668e+02 2.58184890e+07]
#   [2.69479920e+02 4.46309210e+07]
#   [2.70324155e+02 3.70479240e+07]
#   [2.68168872e+02 2.89621630e+07]
#   [2.61029518e+02 2.96036160e+07]
#   [2.56957000e+02 3.00000550e+07]
#   [2.51590038e+02 2.83974440e+07]
#   [2.50434996e+02 2.24910560e+07]
#   [2.53681062e+02 2.92190950e+07]
#   [2.48154784e+02 2.49909050e+07]
#   [2.49090766e+02 2.11900420e+07]
#   [2.48353929e+02 2.24909500e+07]
#   [2.45217392e+02 2.75652590e+07]
#   [2.50036705e+02 2.48336460e+07]
#   [2.54198839e+02 3.07601360e+07]
#   [2.55772086e+02 2.41098490e+07]
#   [2.53063712e+02 2.14731790e+07]
#   [2.52615635e+02 1.73402170e+07]]
#
#  [[2.51241534e+02 2.66533870e+07]
#   [2.47527476e+02 2.83339300e+07]
#   [2.52834695e+02 3.33397210e+07]
#   [2.59675331e+02 3.36202930e+07]
#   [2.64305456e+02 4.60280470e+07]
#   [2.75019466e+02 5.48321400e+07]
#   [2.78235660e+02 6.95273710e+07]
#   [2.71066434e+02 4.34666490e+07]
#   [2.72609809e+02 3.45587040e+07]
#   [2.71126178e+02 3.48733300e+07]
#   [2.76473225e+02 3.66108790e+07]
#   [2.79370787e+02 2.81999620e+07]
#   [2.75198696e+02 2.68402120e+07]
#   [2.74053612e+02 2.18786470e+07]
#   [2.79311044e+02 2.50870320e+07]
#   [2.82835913e+02 2.50534100e+07]
#   [2.87067748e+02 3.27659760e+07]
#   [2.86002321e+02 2.48833420e+07]
#   [2.85952535e+02 2.58242990e+07]
#   [2.83124674e+02 2.20647700e+07]]
#
#  [[2.90353643e+02 2.97703340e+07]
#   [2.88153089e+02 2.31029940e+07]
#   [2.81621128e+02 2.72765890e+07]
#   [2.82278307e+02 2.74034320e+07]
#   [2.88601166e+02 2.42226780e+07]
#   [2.84916980e+02 2.09879170e+07]
#   [2.87565611e+02 2.37911510e+07]
#   [2.87137449e+02 2.01618450e+07]
#   [2.87217107e+02 1.71502710e+07]
#   [2.84887108e+02 2.32443630e+07]
#   [2.84538604e+02 2.16763870e+07]
#   [2.80565658e+02 2.66110140e+07]
#   [2.74242800e+02 4.57722360e+07]
#   [2.94107529e+02 6.44811170e+07]
#   [3.03527095e+02 4.64626380e+07]
#   [3.05946709e+02 3.64696130e+07]
#   [3.04253975e+02 2.12941150e+07]
#   [3.04104616e+02 2.64044310e+07]
#   [3.03098933e+02 2.23607540e+07]
#   [3.04104616e+02 2.25199070e+07]]
#
#  [[3.09322219e+02 2.81970520e+07]
#   [3.07330768e+02 2.13186130e+07]
#   [3.05687820e+02 2.13408290e+07]
#   [3.10975124e+02 3.00780440e+07]
#   [3.08784527e+02 3.16801790e+07]
#   [3.07649400e+02 1.97746960e+07]
#   [3.08137306e+02 1.63365470e+07]
#   [3.10407561e+02 2.67303470e+07]
#   [3.13334994e+02 2.43150120e+07]
#   [3.17845422e+02 2.72759910e+07]
#   [3.17665803e+02 2.75467010e+07]
#   [3.20499788e+02 2.41156640e+07]
#   [3.14592326e+02 3.07971730e+07]
#   [3.13185312e+02 2.33848870e+07]
#   [3.25229750e+02 4.33017430e+07]
#   [3.32184988e+02 3.66306330e+07]
#   [3.30508546e+02 2.95030700e+07]
#   [3.27694519e+02 4.55468580e+07]
#   [3.31875645e+02 2.67738510e+07]
#   [3.34689672e+02 2.58737690e+07]]
#
#  [[3.35228529e+02 2.13070530e+07]
#   [3.32973315e+02 2.03962230e+07]
#   [3.22695129e+02 4.07171290e+07]
#   [3.24571147e+02 2.32777080e+07]
#   [3.26097907e+02 2.25289500e+07]
#   [3.31147191e+02 2.43067530e+07]
#   [3.33582023e+02 2.29512790e+07]
#   [3.36625564e+02 2.60037910e+07]
#   [3.47362776e+02 3.88990750e+07]
#   [3.41604996e+02 4.65519850e+07]
#   [3.37334060e+02 2.63754070e+07]
#   [3.32853569e+02 2.51177990e+07]
#   [3.38990544e+02 2.35567640e+07]
#   [3.34310477e+02 2.31469010e+07]
#   [3.27904074e+02 2.15205820e+07]
#   [3.33861430e+02 2.43541100e+07]
#   [3.35138719e+02 2.02595230e+07]
#   [3.34340414e+02 1.69970420e+07]
#   [3.39818787e+02 2.68327560e+07]
#   [3.37274187e+02 1.25086920e+07]]
#
#  [[3.37433848e+02 1.81723780e+07]
#   [3.40547241e+02 2.81955340e+07]
#   [3.36505818e+02 2.12148240e+07]
#   [3.31127233e+02 3.27914490e+07]
#   [3.31765878e+02 2.66982180e+07]
#   [3.36485860e+02 2.99952620e+07]
#   [3.41934297e+02 2.05671590e+07]
#   [3.44508833e+02 2.83527290e+07]
#   [3.44997795e+02 2.03639270e+07]
#   [3.58728653e+02 6.48727050e+07]
#   [3.54327993e+02 3.97329010e+07]
#   [3.46135381e+02 3.37783950e+07]
#   [3.43041946e+02 6.94053820e+07]
#   [3.44379108e+02 2.67192070e+07]
#   [3.50236676e+02 4.16377390e+07]
#   [3.37054653e+02 5.83837020e+07]
#   [3.30019584e+02 3.96352620e+07]
#   [3.37653382e+02 2.84848680e+07]
#   [3.35208571e+02 2.54460220e+07]
#   [3.35627682e+02 1.83812530e+07]]
#
#  [[3.26806403e+02 2.77612570e+07]
#   [3.25968182e+02 1.83603520e+07]
#   [3.27085810e+02 2.37414840e+07]
#   [3.29410876e+02 1.77415260e+07]
#   [3.25359474e+02 2.23275740e+07]
#   [3.21547564e+02 2.23732680e+07]
#   [3.22246082e+02 2.01137250e+07]
#   [3.20330148e+02 2.43554910e+07]
#   [3.23353731e+02 1.88361390e+07]
#   [3.21178348e+02 1.69662850e+07]
#   [3.20400000e+02 2.06988640e+07]
#   [3.16880000e+02 2.12571610e+07]
#   [3.16480000e+02 2.47550120e+07]
#   [3.21880000e+02 2.40399560e+07]
#   [3.22460000e+02 1.61020240e+07]
#   [3.27000000e+02 2.11663820e+07]
#   [3.19970000e+02 2.32814340e+07]
#   [3.22980000e+02 2.16841040e+07]
#   [3.23700000e+02 1.48084820e+07]
#   [3.28410000e+02 1.92845900e+07]]], shape=(15, 20, 2), dtype=float64)
# ----------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 129ms/step
# 2023-09-19 23:32:22 - src.common.analysis_and_plots - INFO - Plot "LSTM-None-2023-09-19_23-32-22-1.png" saved to "D:\Study 2018 and later\Mignimind Bootcamp\Code\P7-Trading-Bot\figures\LSTM-None-2023-09-19_23-32-22-1.png"
# --------------------------------forecast-----------------------------------
# 0 [[6371576. ]
#  [5526999. ]
#  [5505758. ]
#  [7222078. ]
#  [5240417. ]
#  [5829104.5]
#  [4272747. ]
#  [6755335. ]
#  [4862012. ]
#  [4890527. ]
#  [5072080.5]
#  [4440940.5]
#  [4185226.8]
#  [4155496.5]
#  [7636211.5]
#  [6279844. ]
#  [5344250. ]
#  [6338736.5]
#  [4465460.5]
#  [5325033.5]]
# 1 [[4851491. ]
#  [4769823. ]
#  [4658397. ]
#  [4482696.5]
#  [8376982.5]
#  [9791910. ]
#  [7123315.5]
#  [6845149.5]
#  [4585645.5]
#  [4844230.5]
#  [5007030. ]
#  [3853088.2]
#  [3571200.2]
#  [3993419.8]
#  [4982837. ]
#  [5255897. ]
#  [4271911. ]
#  [4815593. ]
#  [3850315. ]
#  [3853983. ]]
# ----------------------------------------------------------------------------------------------------
# (299,)

# %%
# -----------------------Calculate Errors----------------------------------
naive_forecast = get_naive_forecast(df).iloc[-len(df_test['Adj Close']):]
rmse, mae, mape, mase = calc_errors(df_test['Adj Close'], results, naive_forecast)
save_errors_to_table(config['model']['name'], {'rmse': rmse, 'mae': mae, 'mape': mape, 'mase': mase})
# Out:
# 2023-09-19 23:32:22 - src.common.globals - INFO - Test RMSE: $ 6439005.73
# 2023-09-19 23:32:22 - src.common.globals - INFO - Test MAE : $ 6044060.478
# 2023-09-19 23:32:22 - src.common.globals - INFO - Test MAPE:   22487.114
# 2023-09-19 23:32:22 - src.common.globals - INFO - Test MASE:   1548720.199
# 2023-09-19 23:32:22 - src.common.globals - INFO - Errors saved to for LSTM model to "logs/models_table.csv" file.
